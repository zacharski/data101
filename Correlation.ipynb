# %% [markdown]
# # Correlation

# %% [markdown]
# A correlation is the degree of association between two variables. One of my favorite books on this topic is:
#
# <img src="http://zacharski.org/files/courses/cs419/mg_statistics_big.png" width="350" />
#
# and they illustrate it by looking at
# ## Ladies expenditures on clothes and makeup
#
# <img src="http://zacharski.org/files/courses/cs419/correlation1.png" width="650" />
# <img src="http://zacharski.org/files/courses/cs419/corr2.png" width="650" />
#
# So let's go ahead and create that data in Pandas and show the table:

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
makeup =  [3000, 5000, 12000, 2000, 7000,  15000,  5000,  6000, 8000,  10000]
clothes = [7000, 8000, 25000, 5000, 12000, 30000, 10000, 15000, 20000, 18000]
ladies = ['Ms A','Ms B','Ms C','Ms D','Ms E','Ms F','Ms G','Ms H','Ms I','Ms J',]
monthly = DataFrame({'makeup': makeup, 'clothes': clothes}, index= ladies)
monthly
# Out:
#       clothes  makeup
# Ms A     7000    3000
# Ms B     8000    5000
# Ms C    25000   12000
# Ms D     5000    2000
# Ms E    12000    7000
# Ms F    30000   15000
# Ms G    10000    5000
# Ms H    15000    6000
# Ms I    20000    8000
# Ms J    18000   10000

# %% [markdown]
# and let's show the scatterplot

# %%
# Import package
import matplotlib.pyplot as plt

# Build Scatter plot
plt.scatter(monthly['makeup'], monthly['clothes'])


# Show plot
plt.show()

# %% [markdown]
# That's pretty good. But notice in the picture of the chart from The Manga Guide to Statistics that there is a title to the chart as well as labels for the x and y axis. Can you add those to the chart?
#
#
# <h3 style="color:blue">Task 1: labels</h3>

# %%
# TBD

# %% [markdown]
# When the data points are close to a straight line going up, we say that there is a positive correlation between the two variables. It's sort of like saying:
#
#     Ann: Is there any relationship between how much a person spends on makeup and how much they spend on clothes?
#     Ms. Graph: Yes. The more a person spends on makeup the more she spends on clothes.
#
# Let's look at a few more examples:
#
# ## Weight and calories in 1-3 yr/old children
# This is real data on the weight and calories consumed for children between 1 and 3 years of age.

# %%
weight = [7.7, 7.8, 8.6, 8.5, 8.6, 9, 10.1, 11.5, 11, 10.2, 11.9, 10.4, 9.3, 9.1, 8.5, 11]
calories = [360, 400, 500, 370, 525, 800, 900, 1200, 1000, 1400, 1600, 850, 575, 425, 950, 800]
kids = DataFrame({'weight': weight, 'calories': calories})
kids
# Out:
#     calories  weight
# 0        360     7.7
# 1        400     7.8
# 2        500     8.6
# 3        370     8.5
# 4        525     8.6
# 5        800     9.0
# 6        900    10.1
# 7       1200    11.5
# 8       1000    11.0
# 9       1400    10.2
# 10      1600    11.9
# 11       850    10.4
# 12       575     9.3
# 13       425     9.1
# 14       950     8.5
# 15       800    11.0

# %% [markdown]
# <h3 style="color:blue">Task 2: draw the scatter plot with appropriate labels</h3>
# We are interested in seeing the correlation between weight and calories consumed.

# %%
# Your code here

# %% [markdown]
# <h4 style="color:blue">What do you think? Is there a correlation?</h4>
#
#
#
#
#
#
# ## The stronger the correlation the closer to a straight line:
# The more the datapoints are in a straight line, the sronger the correlation. Let's look at students' midtern and final grades.

# %%
midterm = [65, 70, 72, 75, 78, 78, 80, 83, 87, 87, 90, 90, 92, 93, 95, 100]
final =   [72, 68, 75, 76, 79, 73, 79, 85, 89, 87, 92, 93, 94, 91, 97, 98]
grades = DataFrame({'midterm': midterm, 'final': final})
grades
# Out:
#     final  midterm
# 0      72       65
# 1      68       70
# 2      75       72
# 3      76       75
# 4      79       78
# 5      73       78
# 6      79       80
# 7      85       83
# 8      89       87
# 9      87       87
# 10     92       90
# 11     93       90
# 12     94       92
# 13     91       93
# 14     97       95
# 15     98      100

# %% [markdown]
# <h3 style="color:blue">Task 3: Can you create that scatter plot?</h3>

# %%
# Your code here

# %% [markdown]
# ## The Medicine Hat Tigers
#
# <img src="http://www.vancouversun.com/cms/binary/7353125.jpg" width="350" />
#
# Let's load in some data about players from the Medicine Hat Tigers.
# After that we'll create a few new columns:
#
# * `heightcm` is the height of the player in centimeters (note that the Height column is the player's height in inches)
# * `hometownLength` is the number of characters in the string representing the hometown. for example, number 11, Jordon Hickmott's hometown is Mission BC which has 10 letters as indicated in hometownLength.

# %%
medicineHat = pd.read_csv('https://raw.githubusercontent.com/zacharski/machine-learning/master/data/medicineHatTigers.csv')
medicineHat['heightcm'] = medicineHat['Height'] * 2.54
medicineHat['hometownLength'] = medicineHat['Hometown'].str.len()
medicineHat
# Out:
#                  Name Pos. L/R  Height  Weight  Birthday          Hometown  \
# 0       Brennan Bosch    C   R      68     173  02/14/88  Martensville, SK
# 1        Scott Wasden    C   R      73     188  01/04/88      Westbank, BC
# 2        Colton Grant   LW   L      69     177  03/20/89      Standard, AB
# 3         Darren Helm   LW   L      72     182  01/21/87   St. Andrews, MB
# 4       Derek Dorsett   RW   L      71     178  12/20/86    Kindersley, SK
# 5          Daine Todd    C   R      70     173  01/10/87      Red Deer, AB
# 6       Tyler Swystun   RW   R      71     185  01/15/88      Cochrane, AB
# 7          Matt Lowry    C   R      72     186  03/02/88       Neepawa, MB
# 8   Kevin Undershute    LW   L      72     178  04/12/87  Medicine Hat, AB
# 9        Jerrid Sauer   RW   R      71     196  09/12/87  Medicine Hat, AB
# 10        Tyler Ennis    C   L      69     160  10/06/89      Edmonton, AB
# ...

# %% [markdown]
# Let's explore this data a bit.  (Some of these are screwy examples but they illustrate a point)
#
# <h3 style="color:blue">Task 4: Can you create a scatter plot showing the correlation between height in inches and height in cm?</h3>

# %% [markdown]
# <h3 style="color:blue">Task 5: A scatter plot showing the correlation between a person's height in inches and the number of characters in the hometown</h3>

# %% [markdown]
# <h3 style="color:blue">Task 6: A scatter plot showing the correlation between a person's height in cm and their weight.</h3>

# %% [markdown]
# <h3 style="color:blue">Task 7: Which of these has the best correlation? Which shows no correlation?</h3>
# As you can see, if the scatter plot is on a straight line it has perfect correlation.
#
# And if dots are scattered all over the place than there is likely no correlation.
#
#
# Let's look at some other lines:

# %% [markdown]
# ## negative correlation has a line going downhill
#
# #### the relationship of hair length to a person's height

# %%
height =[62, 64, 65, 68, 69, 70, 67, 65, 72, 73, 74]
hairLength = [7, 10, 6, 4, 5, 4, 5, 8, 1, 1, 3]
cm = [173, 185, 175, 183, 180, 196]
people = DataFrame({'height': height, 'hairLength': hairLength})

plt.scatter(people['height'], people['hairLength'])


xlab = 'Amount Spent on Makeup [in Yen]'
ylab = 'Amount Spent on  Clothes [in Yen]'
title = 'Weight and calories in 1 to 3 yr. old children'

# Add axis labels
plt.xlabel("Height in Inches")
plt.ylabel("Hair Length in Inches")


# Add title
plt.title("Comparison of an Individual's Height to the Length of their Hair")


# Show plot
plt.show()

# %% [markdown]
# So The taller someone is, the shorter their hair.
# <h3 style="color:blue">Task 7: A question</h3>
# Do you think correlation means causation? This means that Do you think as a person gets taller somehow that causes a perons's hair to be shorter?
#
#
#
#
#
#
# ## The Effects of Alcohol on the Dexterity Score
# #### a strong negative correlation

# %%
drinks = list(range(11))
dexterity = [96, 96, 90, 63, 65, 50, 47, 46, 18, 17, 9]
drinking = DataFrame({'drinks': drinks, 'dexterity': dexterity})

plt.scatter(drinking['drinks'], drinking['dexterity'])



# Add axis labels
plt.xlabel("Number of Drinks")
plt.ylabel("Dexterity Score")


# Add title
plt.title("The effects of alcohol consumption on dexterity")


# Show plot
plt.show()

# %% [markdown]
# # Numeric Represenstation of the Strength of the Correlation
#
#
# So far we've looked at correlations visually. The more a scatter plot looks like a straight line the stronger the correlation. If the line goes up from left to right it is a positive correlation. If it goes down it is a negative correlation. We can also determine correlation using a number...
#
# ## Pearson Correlation Coefficient
#
# The Pearson Correlation Coefficient ranges from -1 to 1.
# 1 is perfect positive correlation, -1 is perfect negative. The formula is as follows:
#
# $$r=\frac{\sum_{i=1}^n(x_i - \bar{x})(y_i-\bar{y})}{\sqrt{\sum_{i=1}^n(x_i - \bar{x})}  \sqrt{\sum_{i=1}^n(y_i - \bar{y})}}$$
#
# Let me say immediately that you don't need to know that formula for this class. Should you dive deeper into Data Science you will need to interpret and apply formulas like this, but the good news is that these formulas always look a lot harder than they actually are. (Take it from me -- I had zero real math classes in high school and none in college (I have a Bachelor of Fine Arts degree))
#
# Anyway, let's ignore the formula and think that a number near 1 means a positive correlation; 0 means no correlation, and near -1 means a strong negative correlation.
#
# ### Japanese ladies expensives on makeup and clothes
# Let's go back to our first example.
# First here is the data:

# %%
monthly
# Out:
#       clothes  makeup
# Ms A     7000    3000
# Ms B     8000    5000
# Ms C    25000   12000
# Ms D     5000    2000
# Ms E    12000    7000
# Ms F    30000   15000
# Ms G    10000    5000
# Ms H    15000    6000
# Ms I    20000    8000
# Ms J    18000   10000

# %% [markdown]
# And our Scatter plot looked like this:

# %%
# Import package
import matplotlib.pyplot as plt

# Build Scatter plot
plt.scatter(monthly['makeup'], monthly['clothes'])


# Show plot
plt.show()

# %% [markdown]
# So that looks like a pretty strong positive correlation. To compute Pearson on this data we do:

# %%
monthly.corr()
# Out:
#          clothes   makeup
# clothes  1.00000  0.96802
# makeup   0.96802  1.00000

# %% [markdown]
# So we have a nice table with 1s on the diagonal. The diagonal states the obvious: clothes expenditures are perfectly correlated with clothes expenditures and makeup expenditures are perfectly correlated with makeup expenditures.
#
# The other cells are the interesting ones and they show that the correlation between clothes and makeup is very strong at 0.96802.

# %% [markdown]
# Let's look at the correlation between the number of drinks and dexterity:

# %%
drinking.corr()
# Out:
#            dexterity    drinks
# dexterity   1.000000 -0.979237
# drinks     -0.979237  1.000000

# %% [markdown]
# So -0.97923 indicates a very strong negative correlation

# %% [markdown]
# <h2 style="color:blue">Task 8: School Music Program: a case study</h2>
#
# We are interested in seeing whether a relationship exists between music performance
# grades and students' individual Iowa Test of Basic Skills (ITBS) scores. Let's load in the data

# %%
musicFile = "https://raw.githubusercontent.com/zacharski/machine-learning/master/data/musicITBS.csv"
music = pd.read_csv(musicFile)
music.set_index('Student', inplace=True)

music
# Out:
#          Band  Math  Language  Science
# Student
# 1           3   220       215      220
# 2           4   240       210      225
# 3           3   210       250      235
# 4           2   215       230      210
# 5           4   260       240      220
# 6           3   230       270      250
# 7           4   240       240      220
# 8           4   259       220      240
# 9           3   245       230      250
# 10          4   280       270      230
# 11          5   300       260      220
# 12          2   230       250      225
# 13          3   250       245      235
# 14          4   275       235      210
# 15          3   200       260      220
# 16          2   200       255      250
# 17          4   290       250      220
# 18          3   250       230      240
# 19          4   270       245      250
# 20          4   260       270      230
# 21          3   260       270      260
# 22          4   270       250      230
# 23          5   310       260      260
# ...

# %% [markdown]
# We want to know what test score (math, language, science) that the music performance grade is most highly correlated with. Write code that computes the correlation table. Also, for the most highly correlated pair, please draw a scatter plot. For example, if science is most highly correlated with band draw that scatter plot.

# %%
# Your code here

# %% [markdown]
# Using a scatter plot graph the strongest association

# %% [markdown]
# <h3 style="color:blue">Task 9: What do you think?</h3>
#
# 1. Is knowing a person's music performance grade a good predictor for that person's score in math?  language? science?
#
# 2. Does this study offer support for an argument not to eliminate the music program at our high school because it improves math scores?
#
# 3. Does this study offer support for an argument that eliminating the music program will have no effect on language scores?
